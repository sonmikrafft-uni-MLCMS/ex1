# %% [markdown]
# # Task 2 - First Step of a single Pedestrian

# %% [markdown]
# # A) With the API

# %% [markdown]
# ## 0. Imports

# %%
from helpers.cellular_automaton import fill_from_scenario_file

# %% [markdown]
# ## 1. Loading the scenario
# Now the pedestrians have to interact with each other. Insert five pedestrians in the previous scenario from
# task 2, arranged in a circle in a fairly large distance (30-50m) around a single target in the center of the scenario.

# %%
cellularAutomaton_task3 = fill_from_scenario_file('scenario_files/tasks/scenario_task_3.csv')
cellularAutomaton_task3.visualize_state_grid()
# Out:
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# ...

# %% [markdown]
# ## 2. Simulation
# Run the scenario and report your findings.

# %%
cellularAutomaton_task3.simulate_until_no_change(target_absorbs=False)
cellularAutomaton_task3.visualize_simulation()
# Out:
# Iteration 0:
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# ...

# %% [markdown]
# ## 3. Review of the Simulation
# What is the configuration of the pedestrians around the target after the simulation? Do the pedestrians all reach the target roughly at the same time? They should, because they start at the same distance! If not, implement a way to correctly traverse the space in arbitrary directions with roughly the same speed.

# %%
cellularAutomaton_task3.visualize_state_grid()
# Out:
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# ...

# %% [markdown]
# Looking at the visualization of the entire simulation at each iteration step. We can see that the pedestrians reach the center target at the same iteration number.
# Here, there iteration stops since we explicitely told it to stop when there is no further change and the target is configured to not absorb the pedestrians.

# %% [markdown]
# # B) With the GUI

# %% [markdown]
# ## 0. Imports

# %%
import tkinter as tk
from helpers.gui import GUI

# %% [markdown]
# ## 1. Start the GUI, load the scenario file and run the simulation

# %%
root = tk.Tk()
gui = GUI(root)
root.mainloop()
