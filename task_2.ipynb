# %% [markdown]
# # Task 2 - First Step of a single Pedestrian

# %% [markdown]
# # A) With the API

# %% [markdown]
# ## 0. Imports

# %%
from helpers.cellular_automaton import fill_from_scenario_file

# %% [markdown]
# ## 1. Loading the scenario
# Define a scenario with 50 by 50 cells (2500 in total), a single pedestrian at position (5; 25) and a target 20
# cells away from them at (25; 25).

# %%
cellularAutomaton_task2 = fill_from_scenario_file('scenario_files/tasks/scenario_task_2.csv')
cellularAutomaton_task2.visualize_state_grid()
# Out:
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                           P                                                                        ]
# ...

# %% [markdown]
# ## 2. Simulation
# Simulate the scenario with your cellular automaton for 25 time steps, so that the pedestrian moves to the target and waits there.

# %%
cellularAutomaton_task2.simulate_next_n(n=25, target_absorbs=False, stop_when_no_change=False)
cellularAutomaton_task2.visualize_simulation()
# Out:
# Iteration 0:
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                                                                                                    ]
# [                                                                           P                                                                        ]
# ...

# %% [markdown]
# # B) With the GUI

# %% [markdown]
# ## 0. Imports

# %%
import tkinter as tk
from helpers.gui import GUI

# %% [markdown]
# ## 1. Start the GUI, load the scenario file and run the simulation

# %%
root = tk.Tk()
gui = GUI(root)
root.mainloop()
